# %%
import os
import pyautogui
import time
from os.path import join

# %%
os.chdir('/Users/chrislee/Desktop/images')

# %%
os.getcwd()

# %%
x = 383


while True:

    
    capture = pyautogui.screenshot((str(x)+ '.png'),region=(376,264,2124,1424))
    x += 1
    print('captured: ' + str(x))
# Out:
# captured: 384
# captured: 385
# captured: 386
# captured: 387
# captured: 388
# captured: 389
# captured: 390
# captured: 391
# captured: 392
# captured: 393
# captured: 394
# captured: 395
# captured: 396
# captured: 397
# captured: 398
# captured: 399
# captured: 400
# captured: 401
# captured: 402
# captured: 403
# captured: 404
# captured: 405
# captured: 406
# captured: 407
# captured: 408
# captured: 409
# captured: 410
# captured: 411
# captured: 412
# captured: 413
# captured: 414
# captured: 415
# captured: 416
# captured: 417
# captured: 418
# captured: 419
# captured: 420
# captured: 421
# captured: 422
# captured: 423
# captured: 424
# captured: 425
# captured: 426
# captured: 427
# captured: 428
# captured: 429
# captured: 430
# captured: 431
# captured: 432
# captured: 433
# captured: 434
# captured: 435
# captured: 436
# captured: 437
# captured: 438
# captured: 439
# captured: 440
# captured: 441
# captured: 442
# captured: 443
# captured: 444
# captured: 445
# ...
